# %%
import pymc as pm
import arviz as az
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os 
az.style.use("arviz-darkgrid")

# %%
trace = "sox2.nc"
trace = az.from_netcdf(trace)

# %%
az.plot_trace_dist(trace, compact=True)
az.combine_plots(trace, plots= [(az.plot_rank, {"thin": False}), (az.plot_autocorr, {}), (az.plot_ess, {})])

# %%
visuals = {"credible_interval":{"color":"red"},"point_estimate":{"color":"red"}}
az.plot_pair(trace, group="posterior", visuals=visuals)

# %%
az.combine_plots(trace, plots= [(az.plot_dist, {}), (az.plot_prior_posterior, {})])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 az.combine_plots(trace, plots= [(az.plot_dist, {}), (az.plot_prior_posterior, {})])
#
# File /opt/miniconda3/envs/pymc_env/lib/python3.14/site-packages/arviz_plots/plots/combine.py:148, in combine_plots(dt, plots, var_names, filter_vars, group, coords, sample_dims, expand, plot_names, backend, **pc_kwargs)
#     141 pc = PlotCollection.grid(
#     142     distribution,
#     143     backend=backend,
#     144     **pc_kwargs,
#     145 )
#     147 for name, (plot, kwargs) in zip(plot_names, plots):
# --> 148     pc_i = plot(
#     149         dt,
#     150         backend="none",
#     151         group=group,
#     152         var_names=var_names,
#     153         filter_vars=filter_vars,
#     154         coords=coords,
#     155         sample_dims=sample_dims,
#     156         **kwargs,
#     157     )
#     158     pc.coords = None
#     159     pc.aes = pc_i.aes
#
# File /opt/miniconda3/envs/pymc_env/lib/python3.14/site-packages/arviz_plots/plots/prior_posterior_plot.py:150, in plot_prior_posterior(dt, var_names, filter_vars, group, coords, sample_dims, kind, plot_collection, backend, labeller, aes_by_visuals, visuals, stats, **pc_kwargs)
#     146         backend = plot_collection.backend
#     148 plot_bknd = import_module(f".backend.{backend}", package="arviz_plots")
# --> 150 sample_dims_prior = validate_sample_dims(sample_dims, data=dt.prior)
#     151 sample_dims = validate_sample_dims(sample_dims, data=dt.posterior)
#     152 prior_size = np.prod([dt.prior.sizes[dim] for dim in sample_dims_prior])
#
# File /opt/miniconda3/envs/pymc_env/lib/python3.14/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'DataTree' object has no attribute 'prior'

# %%
az.summary(trace, kind="all")
# Out:
#            mean      sd eti89_lb eti89_ub  ess_bulk  ess_tail r_hat mcse_mean  \
# alpha_s    0.74    0.61    0.058      1.9      2218      1435  1.00     0.011
# alpha_n    0.74    0.59    0.065      1.9      2978      2339  1.00    0.0095
# beta_s    0.085   0.061   0.0099      0.2      3435      3222  1.00   0.00099
# beta_n    0.256   0.186    0.032     0.61      3312      2903  1.00    0.0033
# k_y       0.122    0.07    0.073     0.22      2522      1429  1.00    0.0021
# gamma_y  0.0059  0.0022   0.0039   0.0088      2789      1493  1.00   5.8e-05
#
#          mcse_sd
# alpha_s   0.0092
# alpha_n   0.0084
# beta_s   0.00082
# beta_n    0.0028
# k_y        0.005
# gamma_y  0.00015

# %%
az.mcse(trace)
# Out:
# <xarray.DataTree 'posterior'>
# Group: /posterior
#     Dimensions:  ()
#     Data variables:
#         alpha_s  float64 8B 0.013
#         alpha_n  float64 8B 0.01357
#         beta_s   float64 8B 0.006552
#         beta_n   float64 8B 0.008501
#         k_y      float64 8B 0.0001302
#         gamma_y  float64 8B 5.734e-05

# %%
compare = az.compare(compare_dict={"dimer_trace": dimer_trace, "monomer_trace": monomer_trace})
az.plot_compare(compare)
# Out:
# c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_stats\loo\helper_loo.py:1146: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_stats\loo\helper_loo.py:1146: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
az.psense_summary(trace, round_to=2)
# Out:
# We detected potential issues. For more information on how to interpret the results, please check
# https://arviz-devs.github.io/EABM/Chapters/Sensitivity_checks.html#interpreting-sensitivity-diagnostics-summary
# or read original paper https://doi.org/10.1007/s11222-023-10366-5
#          prior  likelihood                                 diagnosis
# alpha_s   0.22        0.04  potential strong prior / weak likelihood
# alpha_n   0.23        0.05  potential strong prior / weak likelihood
# beta_s    0.24        0.07             potential prior-data conflict
# beta_n    0.24        0.11             potential prior-data conflict
# k_y       0.15        0.11             potential prior-data conflict
# gamma_y   0.12        0.14             potential prior-data conflict

# %%
az.plot_psense_dist(trace, kind="ecdf")

# %%
az.plot_psense_quantities(trace)

# %%
az.plot_ecdf_pit(trace)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 az.plot_ecdf_pit(trace)
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plots\ecdf_plot.py:226, in plot_ecdf_pit(dt, var_names, filter_vars, group, coords, sample_dims, method, envelope_prob, coverage, plot_collection, backend, labeller, aes_by_visuals, visuals, stats, **pc_kwargs)
#     223 if labeller is None:
#     224     labeller = BaseLabeller()
# --> 226 distribution = process_group_variables_coords(
#     227     dt, group=group, var_names=var_names, filter_vars=filter_vars, coords=coords
#     228 )
#     229 sample_dims = validate_sample_dims(sample_dims, data=distribution)
#     230 sample_size = max(
#     231     int(np.prod([distribution[var].sizes.get(dim, 1) for dim in sample_dims]))
#     232     for var in distribution.data_vars
#     233 )
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plots\utils.py:115, in process_group_variables_coords(dt, group, var_names, filter_vars, coords, allow_dict)
#     113     distribution = concat_model_dict(distribution)
#     114 else:
# --> 115     distribution = get_group(dt, group)
#     116     var_names = _var_names(var_names, distribution, filter_vars)
#     117     if var_names is not None:
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plots\utils.py:47, in get_group(data, group, allow_missing)
#      45     return data.dataset
#      46 try:
# ---> 47     data = data[group]
#      48 except KeyError:
#      49     if not allow_missing:
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\xarray\core\datatree.py:1006, in DataTree.__getitem__(self, key)
#    1002 elif isinstance(key, str):
#    1003     # TODO should possibly deal with hashables in general?
#    1004     # path-like: a name of a node/variable, or path to a node/variable
#    1005     path = NodePath(key)
# -> 1006     return self._get_item(path)
#    1007 elif utils.is_list_like(key):
#    1008     # iterable of variable names
#    1009     raise NotImplementedError(
#    1010         "Selecting via tags is deprecated, and selecting multiple items should be "
#    1011         "implemented via .subset"
#    1012     )
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\xarray\core\treenode.py:561, in TreeNode._get_item(self, path)
#     559         child = current_node.get(part)
#     560         if child is None:
# --> 561             raise KeyError(f"Could not find node at {path}")
#     562         current_node = child
#     563 return current_node
#
# KeyError: 'Could not find node at prior_sbc'

# %%
monomer_evidence = monomer_trace.sample_stats["log_marginal_likelihood"].values[-1]
dimer_evidence = dimer_trace.sample_stats["log_marginal_likelihood"].values[-1]
print(f"Monomer log-evidence: {monomer_evidence}")
print(f"Dimer log-evidence: {dimer_evidence}")
# Out:
# Monomer log-evidence: [        nan         nan         nan         nan         nan         nan
#  -9.30682092]
# Dimer log-evidence: [        nan         nan -3.81974033]

# %%
az.plot_pair(
    trace,
    divergences=True,
    divergences_kwargs={"color": "red", "alpha": 0.8}
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 az.plot_pair(
#       2     trace,
#       3     divergences=True,
#       4     divergences_kwargs={"color": "red", "alpha": 0.8}
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plots\pair_plot.py:280, in plot_pair(dt, var_names, filter_vars, group, coords, sample_dims, marginal, marginal_kind, triangle, plot_matrix, backend, labeller, aes_by_visuals, visuals, stats, **pc_kwargs)
#     277     if not marginal:
#     278         pc_kwargs["figure_kwargs"].setdefault("sharey", "row")
# --> 280     plot_matrix = PlotMatrix(
#     281         distribution,
#     282         backend=backend,
#     283         **pc_kwargs,
#     284     )
#     286 aes_by_visuals["scatter"] = {"overlay"}.union(
#     287     aes_by_visuals.get("scatter", plot_matrix.aes_set)
#     288 )
#     289 aes_by_visuals["divergence"] = {"overlay"}.union(aes_by_visuals.get("divergence", {}))
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plot_matrix.py:117, in PlotMatrix.__init__(self, data, facet_dims, aes, backend, figure_kwargs, **kwargs)
#     114 if figure_kwargs is None:
#     115     figure_kwargs = {}
# --> 117 super().__init__(
#     118     data=self._data,
#     119     viz_dt=self._generate_viz_dt(**figure_kwargs),
#     120     aes=aes,
#     121     backend=backend,
#     122     **kwargs,
#     123 )
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plot_collection.py:268, in PlotCollection.__init__(self, data, viz_dt, aes_dt, aes, backend, **kwargs)
#     266     if aes is None:
#     267         aes = {}
# --> 268     self._aes_dt = self.generate_aes_dt(aes, data, **kwargs)
#     269 else:
#     270     self._aes_dt = aes_dt
#
# File c:\Users\danie\miniconda3\envs\pymc_env\Lib\site-packages\arviz_plots\plot_collection.py:542, in PlotCollection.generate_aes_dt(self, aes, data, **kwargs)
#     540 extra_keys = [key for key in kwargs if key not in aes]
#     541 if extra_keys:
# --> 542     raise ValueError(
#     543         f"Keyword arguments {extra_keys} have been passed as **kwargs but "
#     544         "have no active aesthetic mapped to them. Keyword arguments must define "
#     545         "values to use in their respective aesthetic mapping."
#     546     )
#     547 if not hasattr(self, "backend"):
#     548     plot_bknd = import_module(".backend.none", package="arviz_plots")
#
# ValueError: Keyword arguments ['divergences', 'divergences_kwargs'] have been passed as **kwargs but have no active aesthetic mapped to them. Keyword arguments must define values to use in their respective aesthetic mapping.
